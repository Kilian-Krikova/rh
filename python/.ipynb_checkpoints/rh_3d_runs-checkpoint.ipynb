# %%
import numpy as np
import matplotlib.pyplot as plt
import rhanalyze
from helita.sim import rh15d

# %% [markdown]
# # Check RH1.5 and RH
# ## FALC model for H alpha

# %%
rh1d = rhanalyze.rhout('runs/falc_atmos/FALC_82_H6_rhf1d')
rh3d = rhanalyze.rhout('runs/falc_atmos/FALC_82_H6_rhsc3d')

# %%
path_FALC = "runs/falc_atmos/FALC_82_H6_rh15d" # air
data = rh15d.Rh15dout(path_FALC)
# Out:
# --- Read runs/falc_atmos/FALC_82_H6_rh15d/output_aux.hdf5 file.
# --- Read runs/falc_atmos/FALC_82_H6_rh15d/output_indata.hdf5 file.
# --- Read runs/falc_atmos/FALC_82_H6_rh15d/output_ray.hdf5 file.

# %% [markdown]
# Why is the Lyman series missing !!!????

# %%
plt.figure(figsize=[10, 10])
#plt.xlim([400, 450])
plt.xlim([655.5, 657.5])
#plt.ylim([0.5e-9, 1.8e-8])
plt.plot(rh1d.spectrum.waves, rh1d.rays[0].I, linewidth=2.0, label='SE 1D PRD')
plt.plot(rh3d.spectrum.waves, rh3d.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D PRD plane', c='r')
plt.plot(data.ray.wavelength, data.ray.intensity[0,0,:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.legend()

# %% [markdown]
# ## FALC model for Ca H plus H epsilon

# %%
rh1d = rhanalyze.rhout('runs/falc_atmos/FALC_82_CaH_Heps_rhf1d')
rh1d_niter25 = rhanalyze.rhout('runs/falc_atmos/FALC_82_CaH_Heps_rhf1d_niter25')
rh1d_niter = rhanalyze.rhout('runs/falc_atmos/FALC_82_CaH_Heps_rhf1d_niter')
rh1d_niter_crd = rhanalyze.rhout('runs/falc_atmos/FALC_82_CaH_CRD_Heps_rhf1d_niter')
rh1d_niter6 = rhanalyze.rhout('runs/falc_atmos/FALC_82_CaH_Heps_rhf1d_niter1e6')
rh3d = rhanalyze.rhout('runs/falc_atmos/FALC_82_CaH_Heps_rhsc3d')
rh3d_niter = rhanalyze.rhout('runs/falc_atmos/FALC_82_CaH_Heps_rhsc3d_niter')

# %%
path_FALC = "runs/falc_atmos/FALC_82_CaH_Heps_rh15d" # air
data = rh15d.Rh15dout(path_FALC)
path_FALC = "runs/falc_atmos/FALC_82_CaH_Heps_rh15d_new" # air
data_new = rh15d.Rh15dout(path_FALC)
# Out:
# --- Read runs/falc_atmos/FALC_82_CaH_Heps_rh15d/output_aux.hdf5 file.
# --- Read runs/falc_atmos/FALC_82_CaH_Heps_rh15d/output_indata.hdf5 file.
# --- Read runs/falc_atmos/FALC_82_CaH_Heps_rh15d/output_ray.hdf5 file.
# --- Read runs/falc_atmos/FALC_82_CaH_Heps_rh15d_new/output_aux.hdf5 file.
# --- Read runs/falc_atmos/FALC_82_CaH_Heps_rh15d_new/output_indata.hdf5 file.
# --- Read runs/falc_atmos/FALC_82_CaH_Heps_rh15d_new/output_ray.hdf5 file.

# %%
plt.figure(figsize=[10, 10])
#plt.xlim([400, 450])
plt.xlim([396.8, 397.15])
plt.ylim([0.5e-9, 0.8e-8])
#plt.plot(rh1d.spectrum.waves, rh1d.rays[0].I, linewidth=2.0, label='SE 1D PRD')
#plt.plot(rh1d_niter25.spectrum.waves, rh1d_niter25.rays[0].I, linewidth=2.0, label='SE 1D PRD niter 25')
plt.plot(rh1d_niter.spectrum.waves, rh1d_niter.rays[0].I, linewidth=2.0, label='SE 1D PRD')
plt.plot(rh1d_niter_crd .spectrum.waves, rh1d_niter_crd .rays[0].I, linewidth=2.0, label='SE 1D CRD')
#plt.plot(rh1d_niter6.spectrum.waves, rh1d_niter6.rays[0].I, linewidth=2.0, label='SE 1D PRD niter6')
#plt.plot(rh3d.spectrum.waves, rh3d.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D PRD plane', c='r')
plt.plot(rh3d_niter.spectrum.waves, rh3d_niter.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D PRD plane', ls='-.')
plt.plot(data_new.ray.wavelength, data_new.ray.intensity[0,0,:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
#plt.plot(data.ray.wavelength, data.ray.intensity[0,0,:], linewidth=2.0, label='SE 1.5D PRD', ls='--')
plt.legend()

# %% [markdown]
# Ca H shows some differences between rh RH 1D and RH1.5D case for the k2, k3 features. The Hepsilon shows a similar line profile.

# %% [markdown]
# ## cb24bih x345 y264 atmosphere for Ca H plus H epsilon

# %%
from helita.sim import rh15d
path_3D = "/mn/stornext/d18/RoCS/kiliankr/Hepsilon/cb24bih/3d/cb24bih_s385_CaH_Heps_se/" # air
data = rh15d.Rh15dout(path_3D)

path_3D = "/mn/stornext/d18/RoCS/kiliankr/Hepsilon/cb24bih/3d/cb24bih_s385_CaH_Heps_se_nokurucz/" # air
data_old = rh15d.Rh15dout(path_3D)

path_3D_HNEI = '/mn/stornext/d18/RoCS/kiliankr/Hepsilon/cb24bih/3d/cb24bih_s385_CaH_Heps_HNEI_pop'
data_hnei = rh15d.Rh15dout(path_3D_HNEI )

path_3D_HNEI = '/mn/stornext/d18/RoCS/kiliankr/Hepsilon/cb24bih/3d/cb24bih_s385_CaH_Heps_HNEI'
data_hnei_old = rh15d.Rh15dout(path_3D_HNEI)
# Out:
# --- Read /mn/stornext/d18/RoCS/kiliankr/Hepsilon/cb24bih/3d/cb24bih_s385_CaH_Heps_se/output_aux.hdf5 file.
# --- Read /mn/stornext/d18/RoCS/kiliankr/Hepsilon/cb24bih/3d/cb24bih_s385_CaH_Heps_se/output_indata.hdf5 file.
# --- Read /mn/stornext/d18/RoCS/kiliankr/Hepsilon/cb24bih/3d/cb24bih_s385_CaH_Heps_se/output_ray.hdf5 file.
# --- Read /mn/stornext/d18/RoCS/kiliankr/Hepsilon/cb24bih/3d/cb24bih_s385_CaH_Heps_se_nokurucz/output_aux.hdf5 file.
# --- Read /mn/stornext/d18/RoCS/kiliankr/Hepsilon/cb24bih/3d/cb24bih_s385_CaH_Heps_se_nokurucz/output_indata.hdf5 file.
# --- Read /mn/stornext/d18/RoCS/kiliankr/Hepsilon/cb24bih/3d/cb24bih_s385_CaH_Heps_se_nokurucz/output_ray.hdf5 file.
# --- Read /mn/stornext/d18/RoCS/kiliankr/Hepsilon/cb24bih/3d/cb24bih_s385_CaH_Heps_HNEI_pop/output_aux.hdf5 file.
# --- Read /mn/stornext/d18/RoCS/kiliankr/Hepsilon/cb24bih/3d/cb24bih_s385_CaH_Heps_HNEI_pop/output_indata.hdf5 file.
# ...

# %%
rh1d_prd = rhanalyze.rhout('runs/cb24bih_x345_264/cb24bih_s385_x345_y264_467_CaH_Heps_rh15d_niter')
rh3d_prd_plane = rhanalyze.rhout('runs/cb24bih_x345_264/cb24bih_s385_x345_y264_plane3x3_CaH_Heps_rh15d_niter')
rh3d_prd_plane_CaH3d = rhanalyze.rhout('runs/cb24bih_x345_264/cb24bih_s385_x345_y264_plane3x3_CaH3D_PRD_Heps_niter')
rh3d_crd_plane = rhanalyze.rhout('runs/cb24bih_x345_264/cb24bih_s385_x345_y264_plane3x3_CaH_CRD_Heps_rh15d_niter')
rh3d_prd_width1 = rhanalyze.rhout('runs/cb24bih_x345_264/cb24bih_s385_x345_y264_wdith1_CaH_Heps_rh15d')
rh3d_crd_width20 = rhanalyze.rhout('runs/cb24bih_x345_264/cb24bih_s385_x345_y264_width20_CaH_CRD_Heps_rh15d')
rh3d_crd_width20_niter = rhanalyze.rhout('runs/cb24bih_x345_264/cb24bih_s385_x345_y264_width20_CaH_CRD_Heps_rh15d_niter')

# %%
wvl_search_rh1d = 397.1202
wvl_ind_rh1d = np.argmin(np.abs(rh1d_prd.spectrum.waves - wvl_search_rh1d))
wvl_range = 30
wvl_list_rh1d = np.arange(wvl_ind_rh1d-wvl_range, wvl_ind_rh1d+wvl_range)
wvl_Heps_rh1d = rh1d_prd.spectrum.waves[wvl_list_rh1d]

wvl_search_rh15d = 397.1202
wvl_ind_rh15d = np.argmin(np.abs(data.ray.wavelength.data - wvl_search_rh15d))
wvl_range = 30
wvl_list_rh15d = np.arange(wvl_ind_rh15d-wvl_range, wvl_ind_rh15d+wvl_range)
wvl_Heps_rh15d = data.ray.wavelength.data[wvl_list_rh15d]

# %%
x_cen = 345
y_cen = 264
plt.figure(figsize=[10, 10])
#plt.xlim([400, 450])
plt.xlim([396.8, 397.20])
plt.ylim([0.5e-9, 1.5e-8])
plt.plot(rh1d_prd.spectrum.waves, rh1d_prd.rays[0].I, linewidth=2.0, label='SE 1D PRD')
plt.plot(rh3d_prd_plane.spectrum.waves, rh3d_prd_plane.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D PRD plane', ls='--')
#plt.plot(rh3d_prd_plane_CaH3d.spectrum.waves, rh3d_prd_plane_CaH3d.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D PRD plane CaH3D')
plt.plot(rh3d_crd_plane.spectrum.waves, rh3d_crd_plane.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D CRD plane')
#plt.plot(rh3d_prd_width1.spectrum.waves, rh3d_prd_width1.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D PRD width1')
#plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[20,20,:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(rh3d_crd_width20_niter.spectrum.waves, rh3d_crd_width20_niter.rays[0].I[20,20,:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_cen,y_cen,:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
#plt.plot(data_hnei.ray.wavelength, data_hnei.ray.intensity[x_cen,y_cen,:], linewidth=2.0, label='SE 1.5D PRD', ls='--')
plt.legend()

# %% [markdown]
# #### Have a look at the level populations

# %%
x_cen = 345
y_cen = 264

# %%
height = data.atmos.height_scale[0,0,:].dropna('height')

# %%
plt.figure(figsize=[10.087, 7.872])
plt.plot(height/1e6, data.atom_H.populations[8,x_cen,y_cen,:] , label='SE 1.5D', lw=2)
plt.plot(height/1e6, data_hnei.atom_H.populations[8,x_cen,y_cen,:] , label='HNEI 1.5D', lw=2)
plt.plot(height/1e6, rh1d_prd.atoms[1].n[:,-1] , label='SE 1D PRD', lw=2, ls='--')
plt.plot(height/1e6, rh3d_prd_plane.atoms[1].n[0,0,:,-1] , label='SE 3D PRD plane', ls='--', lw=2)
plt.plot(height/1e6, rh3d_crd_width20_niter.atoms[1].n[20,20,:,-1] , label='SE 3D CRD widht20', lw=2)
#plt.plot(height/1e6, data.atmos.electron_density[x_cen,y_cen,:],'--', label='electron density')
plt.yscale('log')
plt.ylabel('number density [m$^{-3}$]')
plt.xlabel('Height [Mm]')
plt.xlim(-1.0, 2.0)
plt.title('Hydrogen protons')
plt.legend()

# %% [markdown]
# #### Have a look at the source function

# %%
wvl_search= 397.1202
wvl_ind_15d = np.argmin(np.abs(data.ray.wavelength_selected.data - wvl_search))
wvl_ind_3d = np.argmin(np.abs(rh1d_prd.spectrum.waves- wvl_search))

# %%
lambda0 = rh1d_prd.atoms[1].transition[11].lambda0
print("lambda_0: ", lambda0)
icore = np.where(rh1d_prd.spectrum.waves == lambda0)
lcore = icore[0][0]
## read the opacity for wavelength index waveno and ray index rayno
rayno  = rh1d_prd.geometry.Nrays-1

rh1d_prd.opacity.read(lcore, rayno)
rh1d_prd.opacity.Source()
# Out:
# lambda_0:  397.1201986897193

# %%
data.ray.tau_one_height[x_cen, y_cen, 603]
data_hnei.ray.tau_one_height[x_cen, y_cen, 603]
# Out:
# <xarray.DataArray 'tau_one_height' ()>
# array(449139.38, dtype=float32)
# Coordinates:
#     wavelength  float64 397.1
#     x           float64 1.643e+07
#     y           float64 -1.257e+07
# Attributes:
#     units:      m
#     long_name:  Height of optical depth unity

# %% [markdown]
# Add source function for 3D CRD case

# %%
plt.figure(figsize=[10.087, 7.872])
plt.plot(height/1e6, data.ray.source_function[x_cen, y_cen, :, wvl_ind_15d] , label='SE 1.5D', lw=2)
plt.plot(height/1e6, data_hnei.ray.source_function[x_cen, y_cen, :,wvl_ind_15d] , label='HNEI 1.5D', lw=2)
plt.plot(height/1e6, rh1d_prd.opacity.S , label='SE 1 PRD', lw=2)

plt.ylabel('Intensity')
plt.xlabel('Height [Mm]')
plt.xlim(-1.0, 2.0)
plt.yscale('log')
plt.title('Source function H epsilon')
plt.legend()

# %% [markdown]
# ## cb24bih_s385_x345_y264 with width 20

# %%
x_cen = 345
y_cen = 264
width = 20
height = 20
inten=data.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data
inten_old=data_old.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data
inten_hnei=data_hnei.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data

# %%
wvl_search= 397.1202
wvl_ind_15d = np.argmin(np.abs(data.ray.wavelength.data - wvl_search))
wvl_ind_3d = np.argmin(np.abs(rh3d_crd_width20_niter.spectrum.waves- wvl_search))
x_min = 325
y_min = 244
x_loc = [20,38,14,5]
y_loc = [20,33,34,21]
x_loc_rh15d = [x_min+x_loc[0], x_min+x_loc[1], x_min+x_loc[2], x_min+x_loc[3]]
y_loc_rh15d = [y_min+y_loc[0], y_min+y_loc[1], y_min+y_loc[2], y_min+y_loc[3]]

#%matplotlib widget
plt.figure(figsize=[16,8])
plt.subplot(2,3,1)
plt.imshow(inten[:,:,wvl_ind_15d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('1.5D SE')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,4)
plt.imshow(rh3d_crd_width20_niter.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('3D SE')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,2)
plt.plot(rh3d_crd_width20_niter.spectrum.waves, rh3d_crd_width20_niter.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(rh3d_prd_plane.spectrum.waves, rh3d_prd_plane.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D PRD plane', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[0], y_loc_rh15d[0],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x20 y20')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.15e-8, 1.5e-8])

plt.subplot(2,3,3)
plt.plot(rh3d_crd_width20_niter.spectrum.waves, rh3d_crd_width20_niter.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[1], y_loc_rh15d[1],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x38 y33')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 0.5e-8])

plt.subplot(2,3,5)
plt.plot(rh3d_crd_width20_niter.spectrum.waves, rh3d_crd_width20_niter.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[2], y_loc_rh15d[2],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x14 y34')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 2.5e-8])

plt.subplot(2,3,6)
plt.plot(rh3d_crd_width20_niter.spectrum.waves, rh3d_crd_width20_niter.rays[0].I[x_loc[3],y_loc[3],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[3], y_loc_rh15d[3],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x5 y21')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 2.5e-8])

plt.tight_layout()

# %% [markdown]
# ## cb24bih_s385_x345_y264 with width 20 aginst width10
# Check if there is a difference because of periodic boundaries

# %%
rh3d_crd_width10 = rhanalyze.rhout('runs/cb24bih_x345_264/cb24bih_s385_x345_y264_width10_CaH_CRD_Heps_rh15d_niter')
rh3d_prd_width10 = rhanalyze.rhout('runs/cb24bih_x345_264/cb24bih_s385_x345_y264_width10_CaH_PRD_Heps_rh15d_niter')

# %%
x_cen = 20
y_cen = 20
width = 10
height = 10
rh3d_int_width20 = rh3d_crd_width20_niter.rays[0].I[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:]

# %%
x_min = 335
y_min = 254
x_loc = [10,3,5]
y_loc = [10,20,7]
x_loc_rh15d = [x_min+x_loc[0], x_min+x_loc[1], x_min+x_loc[2]]
y_loc_rh15d = [y_min+y_loc[0], y_min+y_loc[1], y_min+y_loc[2]]

plt.figure(figsize=[12,4])
rh3d_int = rh3d_crd_width10.rays[0].I[:,:,wvl_ind_3d] # TO set vmin and vmax for all images
plt.subplot(1,3,1)
plt.imshow(rh3d_int_width20[:,:,wvl_ind_3d].T, vmin=np.percentile(rh3d_int,1), vmax=np.percentile(rh3d_int,99))
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)
plt.title('3D SE CRD 20x20')

plt.subplot(1,3,2)
plt.imshow(rh3d_crd_width10.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(rh3d_int,1), vmax=np.percentile(rh3d_int,99))
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)
plt.title('3D SE CRD 10x10')

plt.subplot(1,3,3)
plt.imshow(rh3d_prd_width10.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(rh3d_int,1), vmax=np.percentile(rh3d_int,99))
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)
plt.title('3D SE PRD 10x10')
# Out:
# Text(0.5, 1.0, '3D SE PRD 10x10')

# %%
plt.figure(figsize=[16,6])
plt.subplot(1,3,1)
plt.plot(rh3d_crd_width20_niter.spectrum.waves, rh3d_int_width20[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(rh3d_crd_width10.spectrum.waves, rh3d_crd_width10.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD width10')
plt.plot(rh3d_prd_width10.spectrum.waves, rh3d_prd_width10.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D PRD width10', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[0], y_loc_rh15d[0],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x20 y20')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.15e-8, 1.5e-8])

plt.subplot(1,3,2)
plt.plot(rh3d_crd_width20_niter.spectrum.waves, rh3d_int_width20[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(rh3d_crd_width10.spectrum.waves, rh3d_crd_width10.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD width10',ls='--')
plt.plot(rh3d_prd_width10.spectrum.waves, rh3d_prd_width10.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D PRD width10', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[1], y_loc_rh15d[1],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x3 y20')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.10e-8, 1.0e-8])

plt.subplot(1,3,3)
plt.plot(rh3d_crd_width20_niter.spectrum.waves, rh3d_int_width20[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(rh3d_crd_width10.spectrum.waves, rh3d_crd_width10.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD width10',ls='--')
plt.plot(rh3d_prd_width10.spectrum.waves, rh3d_prd_width10.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D PRD width10', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[2], y_loc_rh15d[2],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x5 y7')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.10e-8, 1.0e-8])
# Out:
# (1e-09, 1e-08)

# %% [markdown]
# ## cb24bih_s385_x78_y221 with width 20

# %%
rh3d_crd_width20 = rhanalyze.rhout('runs/cb24bih_x78_221/cb24bih_s385_x78_y221_width20_CaH_CRD_Heps_rh15d')

# %%
x_cen = 78
y_cen = 221
width = 20
height = 20
inten=data.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data
inten_hnei=data_hnei.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data

# %%
wvl_search= 397.1202
wvl_ind_15d = np.argmin(np.abs(data.ray.wavelength.data - wvl_search))
wvl_ind_3d = np.argmin(np.abs(rh3d_crd_width20_niter.spectrum.waves- wvl_search))
x_min = 58
y_min = 201
x_loc = [21,38,14,5]
y_loc = [18,33,34,21]
x_loc_rh15d = [x_min+x_loc[0], x_min+x_loc[1], x_min+x_loc[2], x_min+x_loc[3]]
y_loc_rh15d = [y_min+y_loc[0], y_min+y_loc[1], y_min+y_loc[2], y_min+y_loc[3]]

#%matplotlib widget
plt.figure(figsize=[12,7])
plt.subplot(2,3,1)
plt.imshow(inten[:,:,wvl_ind_15d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('1.5D SE PRD')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,4)
plt.imshow(rh3d_crd_width20.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('3D SE CRD')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,2)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD width20')
#plt.plot(rh3d_prd_plane.spectrum.waves, rh3d_prd_plane.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D PRD plane', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[0], y_loc_rh15d[0],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x21 y18')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.2e-8])

plt.subplot(2,3,3)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[1], y_loc_rh15d[1],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x38 y33')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.5e-8])

plt.subplot(2,3,5)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[2], y_loc_rh15d[2],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x14 y34')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 2.5e-8])

plt.subplot(2,3,6)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[3],y_loc[3],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[3], y_loc_rh15d[3],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x5 y21')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.0e-8])

plt.tight_layout()

# %% [markdown]
# ## cb24bih_s385_x78_y221 with width 20 aginst width10

# %%
rh3d_crd_width10 = rhanalyze.rhout('runs/cb24bih_x78_221/cb24bih_s385_x78_y221_width10_CaH_CRD_Heps_rh15d_niter')
rh3d_prd_width10 = rhanalyze.rhout('runs/cb24bih_x78_221/cb24bih_s385_x78_y221_width10_CaH_PRD_Heps_rh15d')

# %%
x_cen = 20
y_cen = 20
width = 10
height = 10
rh3d_int_width20 = rh3d_crd_width20.rays[0].I[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:]

# %%
x_min = 68
y_min = 211
x_loc = [10,3,5]
y_loc = [10,20,7]
x_loc_rh15d = [x_min+x_loc[0], x_min+x_loc[1], x_min+x_loc[2]]
y_loc_rh15d = [y_min+y_loc[0], y_min+y_loc[1], y_min+y_loc[2]]

plt.figure(figsize=[12,4])
rh3d_int = rh3d_crd_width10.rays[0].I[:,:,wvl_ind_3d] # TO set vmin and vmax for all images
plt.subplot(1,3,1)
plt.imshow(rh3d_int_width20[:,:,wvl_ind_3d].T, vmin=np.percentile(rh3d_int,1), vmax=np.percentile(rh3d_int,99))
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)
plt.title('3D SE CRD 20x20')

plt.subplot(1,3,2)
plt.imshow(rh3d_crd_width10.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(rh3d_int,1), vmax=np.percentile(rh3d_int,99))
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)
plt.title('3D SE CRD 10x10')

plt.subplot(1,3,3)
plt.imshow(rh3d_prd_width10.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(rh3d_int,1), vmax=np.percentile(rh3d_int,99))
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)
plt.title('3D SE PRD 10x10')
# Out:
# Text(0.5, 1.0, '3D SE PRD 10x10')

# %%
plt.figure(figsize=[16,6])
plt.subplot(1,3,1)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_int_width20[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(rh3d_crd_width10.spectrum.waves, rh3d_crd_width10.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD width10')
plt.plot(rh3d_prd_width10.spectrum.waves, rh3d_prd_width10.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D PRD width10', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[0], y_loc_rh15d[0],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x10 y10')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.0e-8])

plt.subplot(1,3,2)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_int_width20[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(rh3d_crd_width10.spectrum.waves, rh3d_crd_width10.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD width10',ls='--')
plt.plot(rh3d_prd_width10.spectrum.waves, rh3d_prd_width10.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D PRD width10', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[1], y_loc_rh15d[1],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x3 y20')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.0e-8])

plt.subplot(1,3,3)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_int_width20[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(rh3d_crd_width10.spectrum.waves, rh3d_crd_width10.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD width10',ls='--')
plt.plot(rh3d_prd_width10.spectrum.waves, rh3d_prd_width10.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D PRD width10', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[2], y_loc_rh15d[2],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x5 y7')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.2e-8])
# Out:
# (1e-10, 1.2e-08)

# %% [markdown]
# ## cb24bih_s385_x176_y422 with width 20

# %%
rh3d_crd_width20 = rhanalyze.rhout('runs/cb24bih_x176_y422/cb24bih_s385_x176_y422_width20_CaH_CRD_Heps_rh15d_niter')
rh3d_crd_width10 = rhanalyze.rhout('runs/cb24bih_x176_y422/cb24bih_s385_x176_y422_width10_CaH_CRD_Heps_rh15d_niter')
rh3d_prd_width10 = rhanalyze.rhout('runs/cb24bih_x176_y422/cb24bih_s385_x176_y422_width10_CaH_PRD_Heps_rh15d')

# %%
x_cen = 176
y_cen = 422
width = 20
height = 20
inten=data.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data
inten_hnei=data_hnei.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data

# %%
wvl_search= 397.1202
wvl_ind_15d = np.argmin(np.abs(data.ray.wavelength.data - wvl_search))
wvl_ind_3d = np.argmin(np.abs(rh3d_crd_width20_niter.spectrum.waves- wvl_search))
x_min = 156
y_min = 402
x_loc = [21,38,14,5]
y_loc = [16,33,34,21]
x_loc_rh15d = [x_min+x_loc[0], x_min+x_loc[1], x_min+x_loc[2], x_min+x_loc[3]]
y_loc_rh15d = [y_min+y_loc[0], y_min+y_loc[1], y_min+y_loc[2], y_min+y_loc[3]]

#%matplotlib widget
plt.figure(figsize=[12,7])
plt.subplot(2,3,1)
plt.imshow(inten[:,:,wvl_ind_15d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('1.5D SE')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,4)
plt.imshow(rh3d_crd_width20.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('3D SE')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,2)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD width20')
#plt.plot(rh3d_prd_plane.spectrum.waves, rh3d_prd_plane.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D PRD plane', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[0], y_loc_rh15d[0],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x20 y20')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.2e-8])

plt.subplot(2,3,3)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[1], y_loc_rh15d[1],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x38 y33')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.5e-8])

plt.subplot(2,3,5)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[2], y_loc_rh15d[2],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x14 y34')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 2.5e-8])

plt.subplot(2,3,6)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[3],y_loc[3],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[3], y_loc_rh15d[3],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x5 y21')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.0e-8])

plt.tight_layout()

# %% [markdown]
# ## cb24bih_s385_x176_y422 with width 20 aginst width10

# %%
x_cen = 20
y_cen = 20
width = 10
height = 10
rh3d_int_width20 = rh3d_crd_width20.rays[0].I[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:]

# %%
x_min = 166
y_min = 412
x_loc = [9,3,5]
y_loc = [6,20,7]
x_loc_rh15d = [x_min+x_loc[0], x_min+x_loc[1], x_min+x_loc[2]]
y_loc_rh15d = [y_min+y_loc[0], y_min+y_loc[1], y_min+y_loc[2]]

plt.figure(figsize=[12,4])
rh3d_int = rh3d_crd_width10.rays[0].I[:,:,wvl_ind_3d] # TO set vmin and vmax for all images
plt.subplot(1,3,1)
plt.imshow(rh3d_int_width20[:,:,wvl_ind_3d].T, vmin=np.percentile(rh3d_int,1), vmax=np.percentile(rh3d_int,99))
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)
plt.title('3D SE CRD 20x20')

plt.subplot(1,3,2)
plt.imshow(rh3d_crd_width10.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(rh3d_int,1), vmax=np.percentile(rh3d_int,99))
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)
plt.title('3D SE CRD 10x10')

plt.subplot(1,3,3)
plt.imshow(rh3d_prd_width10.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(rh3d_int,1), vmax=np.percentile(rh3d_int,99))
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)
plt.title('3D SE PRD 10x10')
# Out:
# Text(0.5, 1.0, '3D SE PRD 10x10')

# %%
plt.figure(figsize=[16,6])
plt.subplot(1,3,1)
#plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_int_width20[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD width20')
#plt.plot(rh3d_crd_width10.spectrum.waves, rh3d_crd_width10.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD width10')
plt.plot(rh3d_prd_width10.spectrum.waves, rh3d_prd_width10.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D PRD width10', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[0], y_loc_rh15d[0],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x10 y10')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.0e-8])

plt.subplot(1,3,2)
#plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_int_width20[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD width20')
#plt.plot(rh3d_crd_width10.spectrum.waves, rh3d_crd_width10.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD width10',ls='--')
plt.plot(rh3d_prd_width10.spectrum.waves, rh3d_prd_width10.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D PRD width10', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[1], y_loc_rh15d[1],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x3 y20')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.0e-8])

plt.subplot(1,3,3)
#plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_int_width20[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD width20')
#plt.plot(rh3d_crd_width10.spectrum.waves, rh3d_crd_width10.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD width10',ls='--')
plt.plot(rh3d_prd_width10.spectrum.waves, rh3d_prd_width10.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D PRD width10', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[2], y_loc_rh15d[2],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x5 y7')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.2e-8])
# Out:
# (1e-10, 1.2e-08)

# %% [markdown]
# ## cb24bih_s385_x283_y220 with width 20

# %%
rh3d_crd_width20 = rhanalyze.rhout('runs/cb24bih_x283_y220/cb24bih_s385_x283_y220_width20_CaH_CRD_Heps_rh15d')

# %%
x_cen = 283
y_cen = 220
width = 20
height = 20
inten=data.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data
inten_hnei=data_hnei.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e177d55cec9d> in <module>
#       3 width = 20
#       4 height = 20
# ----> 5 inten=data.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data
#       6 inten_hnei=data_hnei.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data
#
# NameError: name 'data' is not defined

# %%
wvl_search= 397.1202
wvl_ind_15d = np.argmin(np.abs(data.ray.wavelength.data - wvl_search))
wvl_ind_3d = np.argmin(np.abs(rh3d_crd_width20.spectrum.waves- wvl_search))
x_min = 263
y_min = 200
x_loc = [21,32,20,22]
y_loc = [16,30,23,20]
x_loc_rh15d = [x_min+x_loc[0], x_min+x_loc[1], x_min+x_loc[2], x_min+x_loc[3]]
y_loc_rh15d = [y_min+y_loc[0], y_min+y_loc[1], y_min+y_loc[2], y_min+y_loc[3]]

#%matplotlib widget
plt.figure(figsize=[12,7])
plt.subplot(2,3,1)
plt.imshow(inten[:,:,wvl_ind_15d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('1.5D SE')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,4)
plt.imshow(rh3d_crd_width20.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('3D SE')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,2)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD width20')
#plt.plot(rh3d_prd_plane.spectrum.waves, rh3d_prd_plane.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D PRD plane', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[0], y_loc_rh15d[0],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x21 y16')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.2e-8])

plt.subplot(2,3,3)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[1], y_loc_rh15d[1],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x32 y30')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.5e-8])

plt.subplot(2,3,5)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[2], y_loc_rh15d[2],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x20 y23')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 2.5e-8])

plt.subplot(2,3,6)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[3],y_loc[3],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[3], y_loc_rh15d[3],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x22 y20')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.0e-8])

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-55741dbf7825> in <module>
#       1 wvl_search= 397.1202
# ----> 2 wvl_ind_15d = np.argmin(np.abs(data.ray.wavelength.data - wvl_search))
#       3 wvl_ind_3d = np.argmin(np.abs(rh3d_crd_width20.spectrum.waves- wvl_search))
#       4 x_min = 263
#       5 y_min = 200
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## cb24bih_s385_x285_y129 with width 20

# %%
rh3d_crd_width20 = rhanalyze.rhout('runs/cb24bih_x285_y129/cb24bih_s385_x285_y129_width20_CaH_CRD_Heps_rh15d')

# %%
x_cen = 285
y_cen = 129
width = 20
height = 20
inten=data.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data
inten_hnei=data_hnei.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data

# %%
wvl_search= 397.1202
wvl_ind_15d = np.argmin(np.abs(data.ray.wavelength.data - wvl_search))
wvl_ind_3d = np.argmin(np.abs(rh3d_crd_width20.spectrum.waves- wvl_search))
x_min = 265
y_min = 109
x_loc = [21,18,20,22]
y_loc = [16,20,23,20]
x_loc_rh15d = [x_min+x_loc[0], x_min+x_loc[1], x_min+x_loc[2], x_min+x_loc[3]]
y_loc_rh15d = [y_min+y_loc[0], y_min+y_loc[1], y_min+y_loc[2], y_min+y_loc[3]]

#%matplotlib widget
plt.figure(figsize=[12,7])
plt.subplot(2,3,1)
plt.imshow(inten[:,:,wvl_ind_15d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('1.5D SE')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,4)
plt.imshow(rh3d_crd_width20.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('3D SE')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,2)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD width20')
#plt.plot(rh3d_prd_plane.spectrum.waves, rh3d_prd_plane.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D PRD plane', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[0], y_loc_rh15d[0],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x21 y16')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.2e-8])

plt.subplot(2,3,3)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[1], y_loc_rh15d[1],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x18 y20')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.5e-8])

plt.subplot(2,3,5)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[2], y_loc_rh15d[2],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x20 y23')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 2.5e-8])

plt.subplot(2,3,6)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[3],y_loc[3],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[3], y_loc_rh15d[3],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x22 y20')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.0e-8])

plt.tight_layout()

# %% [markdown]
# ## cb24bih_s385_x41_y297 with width 20

# %%
rh3d_crd_width20 = rhanalyze.rhout('runs/cb24bih_x41_y297/cb24bih_s385_x41_y297_width20_CaH_CRD_Heps_rh15d')

# %%
x_cen = 41
y_cen = 297
width = 20
height = 20
inten=data.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data
inten_hnei=data_hnei.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data

# %%
wvl_search= 397.1202
wvl_ind_15d = np.argmin(np.abs(data.ray.wavelength.data - wvl_search))
wvl_ind_3d = np.argmin(np.abs(rh3d_crd_width20.spectrum.waves- wvl_search))
x_min = 21
y_min = 277
x_loc = [20,20,20,19]
y_loc = [12,20,25,23]
x_loc_rh15d = [x_min+x_loc[0], x_min+x_loc[1], x_min+x_loc[2], x_min+x_loc[3]]
y_loc_rh15d = [y_min+y_loc[0], y_min+y_loc[1], y_min+y_loc[2], y_min+y_loc[3]]

#%matplotlib widget
plt.figure(figsize=[12,7])
plt.subplot(2,3,1)
plt.imshow(inten[:,:,wvl_ind_15d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('1.5D SE')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,4)
plt.imshow(rh3d_crd_width20.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('3D SE')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,2)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD width20')
#plt.plot(rh3d_prd_plane.spectrum.waves, rh3d_prd_plane.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D PRD plane', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[0], y_loc_rh15d[0],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x20 y12')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.2e-8])

plt.subplot(2,3,3)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[1], y_loc_rh15d[1],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x20 y20')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.5e-8])

plt.subplot(2,3,5)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[2], y_loc_rh15d[2],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x20 y25')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 2.5e-8])

plt.subplot(2,3,6)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[3],y_loc[3],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[3], y_loc_rh15d[3],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x19 y23')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.0e-8])

plt.tight_layout()

# %% [markdown]
# ## cb24bih_s385_x380_y76 with width 20

# %%
rh3d_crd_width20 = rhanalyze.rhout('runs/cb24bih_x380_y76/cb24bih_s385_x380_y76_width20_CaH_CRD_Heps_rh15d')

# %%
x_cen = 380
y_cen = 76
width = 20
height = 20
inten=data.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data
inten_hnei=data_hnei.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data

# %%
wvl_search= 397.1202
wvl_ind_15d = np.argmin(np.abs(data.ray.wavelength.data - wvl_search))
wvl_ind_3d = np.argmin(np.abs(rh3d_crd_width20.spectrum.waves- wvl_search))
x_min = 360
y_min = 56
x_loc = [21,15,21,30]
y_loc = [16,17,21,25]
x_loc_rh15d = [x_min+x_loc[0], x_min+x_loc[1], x_min+x_loc[2], x_min+x_loc[3]]
y_loc_rh15d = [y_min+y_loc[0], y_min+y_loc[1], y_min+y_loc[2], y_min+y_loc[3]]

#%matplotlib widget
plt.figure(figsize=[12,7])
plt.subplot(2,3,1)
plt.imshow(inten[:,:,wvl_ind_15d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('1.5D SE')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,4)
plt.imshow(rh3d_crd_width20.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('3D SE')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,2)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD width20')
#plt.plot(rh3d_prd_plane.spectrum.waves, rh3d_prd_plane.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D PRD plane', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[0], y_loc_rh15d[0],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x21 y16')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.2e-8])

plt.subplot(2,3,3)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[1], y_loc_rh15d[1],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x15 y17')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.5e-8])

plt.subplot(2,3,5)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[2], y_loc_rh15d[2],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x21 y21')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 2.5e-8])

plt.subplot(2,3,6)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[3],y_loc[3],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[3], y_loc_rh15d[3],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x30 y25')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.0e-8])

plt.tight_layout()

# %% [markdown]
# ## cb24bih_s385_x335_y65 with width 20

# %%
rh3d_crd_width20 = rhanalyze.rhout('runs/cb24bih_x335_y65/cb24bih_s385_x335_y65_width20_CaH_CRD_Heps_rh15d')

# %%
x_cen = 335
y_cen = 65
width = 20
height = 20
inten=data.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data
inten_hnei=data_hnei.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data

# %%
wvl_search= 397.1202
wvl_ind_15d = np.argmin(np.abs(data.ray.wavelength.data - wvl_search))
wvl_ind_3d = np.argmin(np.abs(rh3d_crd_width20.spectrum.waves- wvl_search))
x_min = 315
y_min = 45
x_loc = [21,15,21,30]
y_loc = [16,17,21,25]
x_loc_rh15d = [x_min+x_loc[0], x_min+x_loc[1], x_min+x_loc[2], x_min+x_loc[3]]
y_loc_rh15d = [y_min+y_loc[0], y_min+y_loc[1], y_min+y_loc[2], y_min+y_loc[3]]

#%matplotlib widget
plt.figure(figsize=[12,7])
plt.subplot(2,3,1)
plt.imshow(inten[:,:,wvl_ind_15d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('1.5D SE')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,4)
plt.imshow(rh3d_crd_width20.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(inten[:,:,wvl_ind_15d],1), vmax=np.percentile(inten[:,:,wvl_ind_15d],99))
plt.title('3D SE')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(2,3,2)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD width20')
#plt.plot(rh3d_prd_plane.spectrum.waves, rh3d_prd_plane.rays[0].I[0,0,:], linewidth=2.0, label='SE 3D PRD plane', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[0], y_loc_rh15d[0],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x21 y16')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.2e-8])

plt.subplot(2,3,3)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[1], y_loc_rh15d[1],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x15 y17')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.5e-8])

plt.subplot(2,3,5)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[2], y_loc_rh15d[2],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x21 y21')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 2.5e-8])

plt.subplot(2,3,6)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[3],y_loc[3],:], linewidth=2.0, label='SE 3D CRD width20')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[3], y_loc_rh15d[3],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x30 y25')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.0e-8])

plt.tight_layout()

# %% [markdown]
# ## Have a look at the small Ca H and Hepsilon mode atom results

# %%
rh3d_crd_width20 = rhanalyze.rhout('runs/cb24bih_x345_264/cb24bih_s385_x345_y264_width20_CaH_CRD_Heps_rh15d_niter')
rh3d_prd_width20_small = rhanalyze.rhout('runs/cb24bih_x345_264/cb24bih_s385_x345_y264_with_CaH3D_PRD_Heps_small')

# %%
wvl_search= 397.1202
wvl_ind_3d_small = np.argmin(np.abs(rh3d_prd_width20_small.spectrum.waves- wvl_search))
wvl_ind_3d = np.argmin(np.abs(rh3d_crd_width20.spectrum.waves- wvl_search))

x_loc = [20,38,14,5,29,13]
y_loc = [20,33,34,21,14,16]

#%matplotlib widget
plt.figure(figsize=[16,8])
plt.subplot(1,2,1)
plt.imshow(rh3d_crd_width20.rays[0].I[:,:,wvl_ind_3d].T, vmin=np.percentile(rh3d_crd_width20.rays[0].I[:,:,wvl_ind_3d],1), vmax=np.percentile(rh3d_crd_width20.rays[0].I[:,:,wvl_ind_3d],99))
plt.title('3D SE CRD 20x20')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

plt.subplot(1,2,2)
plt.imshow(rh3d_prd_width20_small.rays[0].I[:,:,wvl_ind_3d_small].T, vmin=np.percentile(rh3d_crd_width20.rays[0].I[:,:,wvl_ind_3d],1), vmax=np.percentile(rh3d_crd_width20.rays[0].I[:,:,wvl_ind_3d],99))
plt.title('3D SE PRD 20x20 small atom')
plt.scatter(x_loc, y_loc, s=30, marker='x',c='red', lw=2)

# %%
x_cen = 345
y_cen = 264
width = 20
height = 20
inten=data.ray.intensity[x_cen-width:x_cen+width+1, y_cen-height:y_cen+height+1,:].data

# %%
x_min = 325
y_min = 244

x_loc_rh15d = [x_min+x_loc[0], x_min+x_loc[1], x_min+x_loc[2], x_min+x_loc[3], x_min+x_loc[4], x_min+x_loc[5]]
y_loc_rh15d = [y_min+y_loc[0], y_min+y_loc[1], y_min+y_loc[2], y_min+y_loc[3], y_min+y_loc[4], y_min+y_loc[5]]

plt.figure(figsize=[16,8])
plt.subplot(2,3,1)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D CRD')
plt.plot(rh3d_prd_width20_small.spectrum.waves, rh3d_prd_width20_small.rays[0].I[x_loc[0],y_loc[0],:], linewidth=2.0, label='SE 3D PRD small atom', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[0], y_loc_rh15d[0],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x20 y20')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.2e-8])

plt.subplot(2,3,2)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D CRD')
plt.plot(rh3d_prd_width20_small.spectrum.waves, rh3d_prd_width20_small.rays[0].I[x_loc[1],y_loc[1],:], linewidth=2.0, label='SE 3D PRD small atom', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[1], y_loc_rh15d[1],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x38 y33')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.5e-8])

plt.subplot(2,3,3)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D CRD')
plt.plot(rh3d_prd_width20_small.spectrum.waves, rh3d_prd_width20_small.rays[0].I[x_loc[2],y_loc[2],:], linewidth=2.0, label='SE 3D PRD small atom', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[2], y_loc_rh15d[2],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x14 y34')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 2.5e-8])

plt.subplot(2,3,4)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[3],y_loc[3],:], linewidth=2.0, label='SE 3D CRD')
plt.plot(rh3d_prd_width20_small.spectrum.waves, rh3d_prd_width20_small.rays[0].I[x_loc[3],y_loc[3],:], linewidth=2.0, label='SE 3D PRD small atom', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[3], y_loc_rh15d[3],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x5 y21')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.0e-8])

plt.subplot(2,3,5)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[4],y_loc[4],:], linewidth=2.0, label='SE 3D CRD')
plt.plot(rh3d_prd_width20_small.spectrum.waves, rh3d_prd_width20_small.rays[0].I[x_loc[4],y_loc[4],:], linewidth=2.0, label='SE 3D PRD small atom', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[4], y_loc_rh15d[4],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x29 y14')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.0e-8])

plt.subplot(2,3,6)
plt.plot(rh3d_crd_width20.spectrum.waves, rh3d_crd_width20.rays[0].I[x_loc[5],y_loc[5],:], linewidth=2.0, label='SE 3D CRD')
plt.plot(rh3d_prd_width20_small.spectrum.waves, rh3d_prd_width20_small.rays[0].I[x_loc[5],y_loc[5],:], linewidth=2.0, label='SE 3D PRD small atom', ls='--')
plt.plot(data.ray.wavelength, data.ray.intensity[x_loc_rh15d[5], y_loc_rh15d[5],:], linewidth=2.0, label='SE 1.5D PRD', ls='--', c='cyan')
plt.title('x13 y16')
plt.legend()
plt.xlim([396.8, 397.34])
plt.ylim([0.01e-8, 1.0e-8])

plt.tight_layout()

# %%
data.atom_H.Rji_continuum[0,0,0,100]
# Out:
# <xarray.DataArray 'Rji_continuum' ()>
# array(1.018706e-05)
# Coordinates:
#     x        float64 0.0
#     y        float64 -0.0

# %% [markdown]
# Run for mor small boxes:
# x=384 y=352
# x=176 y=422

# %% [markdown]
# ## Construct a model atom for 3D

# %%
x=345
y=264
n1 = data.atom_H.populations[0,...]
n2 = data.atom_H.populations[1,...]
n3 = data.atom_H.populations[2,...]
n4 = data.atom_H.populations[3,...]
n5 = data.atom_H.populations[4,...]
n6 = data.atom_H.populations[5,...]
n7 = data.atom_H.populations[6,...]
n8 = data.atom_H.populations[7,...]
nH_ion = data.atom_H.populations[8,...]

n1_out = n1*(data.atom_H.Rij_line[0,...]+data.atom_H.Cij_line[0,...] + data.atom_H.Rij_line[1,...]+data.atom_H.Cij_line[1,...] + data.atom_H.Rij_line[2,...]+data.atom_H.Cij_line[2,...] + data.atom_H.Rij_line[3,...]+data.atom_H.Cij_line[3,...] + data.atom_H.Rij_line[4,...]+data.atom_H.Cij_line[4,...] +
             data.atom_H.Rij_line[5,...]+data.atom_H.Cij_line[5,...] + data.atom_H.Rij_line[6,...]+data.atom_H.Cij_line[6,...] + data.atom_H.Rij_continuum[0,...]+data.atom_H.Cij_continuum[0,...])

n2_n1_in = n2*(data.atom_H.Rji_line[0,...] + data.atom_H.Cji_line[0,...])
n3_n1_in = n3*(data.atom_H.Rji_line[1,...] + data.atom_H.Cji_line[1,...])
n4_n1_in = n4*(data.atom_H.Rji_line[2,...] + data.atom_H.Cji_line[2,...])
n5_n1_in = n5*(data.atom_H.Rji_line[3,...] + data.atom_H.Cji_line[3,...])
n6_n1_in = n6*(data.atom_H.Rji_line[4,...] + data.atom_H.Cji_line[4,...])
n7_n1_in = n7*(data.atom_H.Rji_line[5,...] + data.atom_H.Cji_line[5,...])
n8_n1_in = n8*(data.atom_H.Rji_line[6,...] + data.atom_H.Cji_line[6,...])
nc_n1_in = nH_ion*(data.atom_H.Rji_continuum[0,...] + data.atom_H.Cji_continuum[0,...])

# %%
n2_n1_frac = n2_n1_in/n1_out
n3_n1_frac = n3_n1_in/n1_out
n4_n1_frac = n4_n1_in/n1_out
n5_n1_frac = n5_n1_in/n1_out
n6_n1_frac = n6_n1_in/n1_out
n7_n1_frac = n7_n1_in/n1_out
n8_n1_frac = n8_n1_in/n1_out
nc_n1_frac = nc_n1_in/n1_out

# %%
x = 352
y = 271
height_Mm = data.atmos.height_scale[x,y,:]/1e6
plt.figure()
plt.plot(height_Mm, n2_n1_frac[x,y,:], label='n2 to n1')
plt.plot(height_Mm, n3_n1_frac[x,y,:], label='n3 to n1')
plt.plot(height_Mm, n4_n1_frac[x,y,:], label='n4 to n1')
plt.plot(height_Mm, n5_n1_frac[x,y,:], label='n5 to n1')
plt.plot(height_Mm, n6_n1_frac[x,y,:], label='n6 to n1')
plt.plot(height_Mm, n7_n1_frac[x,y,:], label='n7 to n1')
plt.plot(height_Mm, n8_n1_frac[x,y,:], label='n8 to n1')
plt.plot(height_Mm, nc_n1_frac[x,y,:], label='nc to n1')
plt.xlim([0.0,2])
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
height
# Out:
# 10

# %%
n2_n1_net = n2_n1_in -n1*(data.atom_H.Rij_line[0,...]+data.atom_H.Cij_line[0,...])

# %%
plt.figure()
plt.plot(height_Mm, n2_n1_net[x,y,:])
plt.xlim([0.0,2])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (0.0, 2.0)

# %% [markdown]
# ## Location to calculate in 3D
# x=462, y=490 does not work making atmosphere
# x=403, y=410  crashed
# x=200, y=392  crashed
# x=55, y=350  not loadable but converged, same after rerun
# x=150, y=281  crashed
# x=41, y=297  converged
# x=487, y=262 does not work making atmosphere
# x=283, y=220  converged
# x=285, y=129 converged
# x=468, y=83  not loadable but converged, same after rerun
# x=380, y=76 converged
# x=335, y=65  converged
# x=62, y=63 not loadable but converged, same after rerun
# x=135, y=273 running
# -----

# %% [markdown]
# ## Try new source function description
# ### n_2/n_1

# %%
data.atom_H
# Out:
# <xarray.Dataset>
# Dimensions:          (continuum: 8, height: 467, level: 9, line: 28, x: 504, y: 504)
# Coordinates:
#   * x                (x) float64 0.0 4.762e+04 9.524e+04 ... 2.391e+07 2.395e+07
#   * y                (y) float64 -0.0 -4.762e+04 ... -2.391e+07 -2.395e+07
# Dimensions without coordinates: continuum, height, level, line
# Data variables:
#     Cij_continuum    (continuum, x, y, height) float32 ...
#     Cij_line         (line, x, y, height) float32 ...
#     Cji_continuum    (continuum, x, y, height) float32 ...
#     Cji_line         (line, x, y, height) float32 ...
#     Rij_continuum    (continuum, x, y, height) float32 ...
#     Rij_line         (line, x, y, height) float32 ...
#     Rji_continuum    (continuum, x, y, height) float32 ...
#     Rji_line         (line, x, y, height) float32 ...
#     populations      (level, x, y, height) float32 ...
#     populations_LTE  (level, x, y, height) float32 ...
# Attributes:
#     nlevel:      9
# ...

# %%
# Paschen series n=3, rh=2
paschen_start = 13
paschen_end = 17+1
paschen_cont = 2

paschen_rates_line_lyman = data.atom_H.Cji_line[1,...].data + data.atom_H.Rji_line[1,...].data
paschen_rates_line_balmer = data.atom_H.Cji_line[7,...].data + data.atom_H.Rji_line[7,...].data
paschen_rates_line = data.atom_H.Cij_line[paschen_start:paschen_end,...].data + data.atom_H.Rij_line[paschen_start:paschen_end,...].data
paschen_rates_cont = data.atom_H.Cij_continuum[paschen_cont,...].data + data.atom_H.Rij_continuum[paschen_cont,...].data
paschen_rates_out =  np.concatenate((paschen_rates_line_lyman[np.newaxis], paschen_rates_line_balmer[np.newaxis], paschen_rates_line, paschen_rates_cont[np.newaxis]))


P_3 = np.sum(paschen_rates_out, axis=0)
p_31 = paschen_rates_out[0,...]/P_3
p_32 = paschen_rates_out[1,...]/P_3
p_34 = paschen_rates_out[2,...]/P_3
p_35 = paschen_rates_out[3,...]/P_3
p_36 = paschen_rates_out[4,...]/P_3
p_37 = paschen_rates_out[5,...]/P_3
p_38 = paschen_rates_out[6,...]/P_3
p_39 = paschen_rates_out[7,...]/P_3

# %%
# Brackett series n=4, rh=3
brackett_start = 18
brackett_end = 21+1
brackett_cont = 3

brackett_rates_line_lyman = data.atom_H.Cji_line[2,...].data + data.atom_H.Rji_line[2,...].data
brackett_rates_line_balmer = data.atom_H.Cji_line[8,...].data + data.atom_H.Rji_line[8,...].data
brackett_rates_line_paschen = data.atom_H.Cji_line[13,...].data + data.atom_H.Rji_line[13,...].data
brackett_rates_line = data.atom_H.Cij_line[brackett_start:brackett_end,...].data + data.atom_H.Rij_line[brackett_start:brackett_end,...].data
brackett_rates_cont = data.atom_H.Cij_continuum[brackett_cont,...].data + data.atom_H.Rij_continuum[brackett_cont,...].data
brackett_rates_out =  np.concatenate((brackett_rates_line_lyman[np.newaxis], brackett_rates_line_balmer[np.newaxis], brackett_rates_line_paschen[np.newaxis], brackett_rates_line, brackett_rates_cont[np.newaxis]))


P_4 = np.sum(brackett_rates_out, axis=0)
p_41 = brackett_rates_out[0,...]/P_4
p_42 = brackett_rates_out[1,...]/P_4
p_43 = brackett_rates_out[2,...]/P_4
p_45 = brackett_rates_out[3,...]/P_4
p_46 = brackett_rates_out[4,...]/P_4
p_47 = brackett_rates_out[5,...]/P_4
p_48 = brackett_rates_out[6,...]/P_4
p_49 = brackett_rates_out[7,...]/P_4

# %%
# Pfund series n=5, rh=4
pfund_start = 22
pfund_end = 24+1
pfund_cont = 4

pfund_rates_line_lyman = data.atom_H.Cji_line[3,...].data + data.atom_H.Rji_line[3,...].data
pfund_rates_line_balmer = data.atom_H.Cji_line[9,...].data + data.atom_H.Rji_line[9,...].data
pfund_rates_line_paschen = data.atom_H.Cji_line[14,...].data + data.atom_H.Rji_line[14,...].data
pfund_rates_line_brackett = data.atom_H.Cji_line[18,...].data + data.atom_H.Rji_line[18,...].data
pfund_rates_line = data.atom_H.Cij_line[pfund_start:pfund_end,...].data + data.atom_H.Rij_line[pfund_start:pfund_end,...].data
pfund_rates_cont = data.atom_H.Cij_continuum[pfund_cont,...].data + data.atom_H.Rij_continuum[pfund_cont,...].data
pfund_rates_out =  np.concatenate((pfund_rates_line_lyman[np.newaxis], pfund_rates_line_balmer[np.newaxis], pfund_rates_line_paschen[np.newaxis], pfund_rates_line_brackett[np.newaxis], pfund_rates_line, pfund_rates_cont[np.newaxis]))


P_5 = np.sum(pfund_rates_out, axis=0)
p_51 = pfund_rates_out[0,...]/P_5
p_52 = pfund_rates_out[1,...]/P_5
p_53 = pfund_rates_out[2,...]/P_5
p_54 = pfund_rates_out[3,...]/P_5
p_56 = pfund_rates_out[4,...]/P_5
p_57 = pfund_rates_out[5,...]/P_5
p_58 = pfund_rates_out[6,...]/P_5
p_59 = pfund_rates_out[7,...]/P_5

# %%
# Humphreys n=6, rh=5
humphreys_start = 25
humphreys_end = 26+1
humphreys_cont = 5

humphreys_rates_line_lyman = data.atom_H.Cji_line[4,...].data + data.atom_H.Rji_line[4,...].data
humphreys_rates_line_balmer = data.atom_H.Cji_line[10,...].data + data.atom_H.Rji_line[10,...].data
humphreys_rates_line_paschen = data.atom_H.Cji_line[15,...].data + data.atom_H.Rji_line[15,...].data
humphreys_rates_line_brackett = data.atom_H.Cji_line[19,...].data + data.atom_H.Rji_line[19,...].data
humphreys_rates_line_pfund = data.atom_H.Cji_line[22,...].data + data.atom_H.Rji_line[22,...].data
humphreys_rates_line = data.atom_H.Cij_line[humphreys_start:humphreys_end,...].data + data.atom_H.Rij_line[humphreys_start:humphreys_end,...].data
humphreys_rates_cont = data.atom_H.Cij_continuum[humphreys_cont,...].data + data.atom_H.Rij_continuum[humphreys_cont,...].data
humphreys_rates_out =  np.concatenate((humphreys_rates_line_lyman[np.newaxis], humphreys_rates_line_balmer[np.newaxis], humphreys_rates_line_paschen[np.newaxis], humphreys_rates_line_brackett[np.newaxis], humphreys_rates_line_pfund[np.newaxis], humphreys_rates_line, humphreys_rates_cont[np.newaxis]))


P_6 = np.sum(humphreys_rates_out, axis=0)
p_61 = humphreys_rates_out[0,...]/P_6
p_62 = humphreys_rates_out[1,...]/P_6
p_63 = humphreys_rates_out[2,...]/P_6
p_64 = humphreys_rates_out[3,...]/P_6
p_65 = humphreys_rates_out[4,...]/P_6
p_67 = humphreys_rates_out[5,...]/P_6
p_68 = humphreys_rates_out[6,...]/P_6
p_69 = humphreys_rates_out[7,...]/P_6

# %%
# Kriki n=7, rh=6
kriki_start = 27
kriki_end = 27+1
kriki_cont = 6

kriki_rates_line_lyman = data.atom_H.Cji_line[5,...].data + data.atom_H.Rji_line[5,...].data
kriki_rates_line_balmer = data.atom_H.Cji_line[11,...].data + data.atom_H.Rji_line[11,...].data
kriki_rates_line_paschen = data.atom_H.Cji_line[16,...].data + data.atom_H.Rji_line[16,...].data
kriki_rates_line_brackett = data.atom_H.Cji_line[20,...].data + data.atom_H.Rji_line[20,...].data
kriki_rates_line_pfund = data.atom_H.Cji_line[23,...].data + data.atom_H.Rji_line[23,...].data
kriki_rates_line_humphreys = data.atom_H.Cji_line[25,...].data + data.atom_H.Rji_line[25,...].data
kriki_rates_line = data.atom_H.Cij_line[kriki_start:kriki_end,...].data + data.atom_H.Rij_line[kriki_start:kriki_end,...].data
kriki_rates_cont = data.atom_H.Cij_continuum[kriki_cont,...].data + data.atom_H.Rij_continuum[kriki_cont,...].data
kriki_rates_out =  np.concatenate((kriki_rates_line_lyman[np.newaxis], kriki_rates_line_balmer[np.newaxis], kriki_rates_line_paschen[np.newaxis], kriki_rates_line_brackett[np.newaxis], kriki_rates_line_pfund[np.newaxis], kriki_rates_line_humphreys[np.newaxis], kriki_rates_line, kriki_rates_cont[np.newaxis]))


P_7 = np.sum(kriki_rates_out, axis=0)
p_71 = kriki_rates_out[0,...]/P_7
p_72 = kriki_rates_out[1,...]/P_7
p_73 = kriki_rates_out[2,...]/P_7
p_74 = kriki_rates_out[3,...]/P_7
p_75 = kriki_rates_out[4,...]/P_7
p_76 = kriki_rates_out[5,...]/P_7
p_78 = kriki_rates_out[6,...]/P_7
p_79 = kriki_rates_out[7,...]/P_7

# %%
# Kriki2 n=8, rh=7
#kriki_start = 27
#kriki_end = 27+1
kriki2_cont = 7

kriki2_rates_line_lyman = data.atom_H.Cji_line[6,...].data + data.atom_H.Rji_line[6,...].data
kriki2_rates_line_balmer = data.atom_H.Cji_line[12,...].data + data.atom_H.Rji_line[12,...].data
kriki2_rates_line_paschen = data.atom_H.Cji_line[17,...].data + data.atom_H.Rji_line[17,...].data
kriki2_rates_line_brackett = data.atom_H.Cji_line[21,...].data + data.atom_H.Rji_line[21,...].data
kriki2_rates_line_pfund = data.atom_H.Cji_line[24,...].data + data.atom_H.Rji_line[24,...].data
kriki2_rates_line_humphreys = data.atom_H.Cji_line[26,...].data + data.atom_H.Rji_line[26,...].data
kriki2_rates_line_kriki = data.atom_H.Cji_line[27,...].data + data.atom_H.Rji_line[27,...].data
#kriki_rates_line = data.atom_H.Cij_line[kriki_start:kriki_end,...].data + data.atom_H.Rij_line[kriki_start:kriki_end,...].data
kriki2_rates_cont = data.atom_H.Cij_continuum[kriki2_cont,...].data + data.atom_H.Rij_continuum[kriki2_cont,...].data
kriki2_rates_out =  np.concatenate((kriki2_rates_line_lyman[np.newaxis], kriki2_rates_line_balmer[np.newaxis], kriki2_rates_line_paschen[np.newaxis], kriki2_rates_line_brackett[np.newaxis], kriki2_rates_line_pfund[np.newaxis], kriki2_rates_line_humphreys[np.newaxis], kriki2_rates_line_kriki[np.newaxis], kriki2_rates_cont[np.newaxis]))


P_8 = np.sum(kriki2_rates_out, axis=0)
p_81 = kriki2_rates_out[0,...]/P_8
p_82 = kriki2_rates_out[1,...]/P_8
p_83 = kriki2_rates_out[2,...]/P_8
p_84 = kriki2_rates_out[3,...]/P_8
p_85 = kriki2_rates_out[4,...]/P_8
p_86 = kriki2_rates_out[5,...]/P_8
p_87 = kriki2_rates_out[6,...]/P_8
p_89 = kriki2_rates_out[7,...]/P_8

# %%
# Continuum n=9, rh=8

rates_cont = data.atom_H.Cji_continuum.data + data.atom_H.Rji_continuum.data

P_9 = np.sum(rates_cont, axis=0)
p_91 = rates_cont[0,...]/P_9
p_92 = rates_cont[1,...]/P_9
p_93 = rates_cont[2,...]/P_9
p_94 = rates_cont[3,...]/P_9
p_95 = rates_cont[4,...]/P_9
p_96 = rates_cont[5,...]/P_9
p_97 = rates_cont[6,...]/P_9
p_98 = rates_cont[7,...]/P_9

# %% [markdown]
# ### Create matrix

# %%
x = 0
y = 0
height = -1
matrix = np.array([[1, -p_34[x,y,height], -p_35[x,y,height], -p_36[x,y,height], -p_37[x,y,height], -p_38[x,y,height], -p_39[x,y,height]],
                   [-p_43[x,y,height], 1, -p_45[x,y,height], -p_46[x,y,height], -p_47[x,y,height], -p_48[x,y,height], -p_49[x,y,height]],
                   [-p_53[x,y,height], -p_54[x,y,height], 1, -p_56[x,y,height], -p_57[x,y,height], -p_58[x,y,height], -p_59[x,y,height]],
                   [-p_63[x,y,height], -p_64[x,y,height], -p_65[x,y,height], 1, -p_67[x,y,height], -p_68[x,y,height], -p_69[x,y,height]],
                   [-p_73[x,y,height], -p_74[x,y,height], -p_75[x,y,height], -p_76[x,y,height], 1, -p_78[x,y,height], -p_79[x,y,height]],
                   [-p_83[x,y,height], -p_84[x,y,height], -p_85[x,y,height], -p_86[x,y,height], -p_87[x,y,height], 1, -p_89[x,y,height]],
                   [-p_93[x,y,height], -p_94[x,y,height], -p_95[x,y,height], -p_96[x,y,height], -p_97[x,y,height], -p_98[x,y,height], 1]
                  ])
sol_vector = np.array([p_32[x,y,height], p_42[x,y,height], p_52[x,y,height], p_62[x,y,height], p_72[x,y,height], p_82[x,y,height], p_92[x,y,height]])

# %%
sol_vector
# Out:
# array([8.1546739e-02, 4.4836202e-03, 7.4040622e-04, 3.0931635e-04,
#        2.7556671e-04, 2.5695530e-09, 5.0416829e-06], dtype=float32)

# %%
q_kij = np.linalg.inv(matrix).dot(sol_vector)
q_kji = 1-q_kij

# %%
q_kij
# Out:
# array([ 0.09583094,  0.02287328,  0.01210912,  0.0096709 ,  0.00850513,
#        -0.00024345, -0.00018342])

# %%
P_12 = data.atom_H.Cij_line[0,...].data + data.atom_H.Rij_line[0,...].data
P_13 = data.atom_H.Cij_line[1,...].data + data.atom_H.Rij_line[1,...].data
P_14 = data.atom_H.Cij_line[2,...].data + data.atom_H.Rij_line[2,...].data
P_15 = data.atom_H.Cij_line[3,...].data + data.atom_H.Rij_line[3,...].data
P_16 = data.atom_H.Cij_line[4,...].data + data.atom_H.Rij_line[4,...].data
P_17 = data.atom_H.Cij_line[5,...].data + data.atom_H.Rij_line[5,...].data
P_18 = data.atom_H.Cij_line[6,...].data + data.atom_H.Rij_line[6,...].data
P_19 = data.atom_H.Cij_continuum[0,...].data + data.atom_H.Rij_continuum[0,...].data

# %%
P_21 = data.atom_H.Cji_line[0,...].data + data.atom_H.Rji_line[0,...].data
P_23 = data.atom_H.Cij_line[7,...].data + data.atom_H.Rij_line[7,...].data
P_24 = data.atom_H.Cij_line[8,...].data + data.atom_H.Rij_line[8,...].data
P_25 = data.atom_H.Cij_line[9,...].data + data.atom_H.Rij_line[9,...].data
P_26 = data.atom_H.Cij_line[10,...].data + data.atom_H.Rij_line[10,...].data
P_27 = data.atom_H.Cij_line[11,...].data + data.atom_H.Rij_line[11,...].data
P_28 = data.atom_H.Cij_line[12,...].data + data.atom_H.Rij_line[12,...].data
P_29 = data.atom_H.Cij_continuum[1,...].data + data.atom_H.Rij_continuum[1,...].data

# %%
n2_n1_frac = ((P_12[x,y,height] + P_13[x,y,height]*q_kij[0] + P_14[x,y,height]*q_kij[1] + P_15[x,y,height]*q_kij[2] + P_16[x,y,height]*q_kij[3] + P_17[x,y,height]*q_kij[4] + P_18[x,y,height]*q_kij[5] + P_19[x,y,height]*q_kij[6])/
              (P_21[x,y,height] + P_23[x,y,height]*q_kji[0] + P_24[x,y,height]*q_kji[1] + P_25[x,y,height]*q_kji[2] + P_26[x,y,height]*q_kji[3] + P_27[x,y,height]*q_kji[4] + P_28[x,y,height]*q_kji[5] + P_29[x,y,height]*q_kji[6]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9222ab9dbe6d> in <module>
# ----> 1 n2_n1_frac = ((P_12[x,y,height] + P_13[x,y,height]*q_kij[0] + P_14[x,y,height]*q_kij[1] + P_15[x,y,height]*q_kij[2] + P_16[x,y,height]*q_kij[3] + P_17[x,y,height]*q_kij[4] + P_18[x,y,height]*q_kij[5] + P_19[x,y,height]*q_kij[6])/
#       2               (P_21[x,y,height] + P_23[x,y,height]*q_kji[0] + P_24[x,y,height]*q_kji[1] + P_25[x,y,height]*q_kji[2] + P_26[x,y,height]*q_kji[3] + P_27[x,y,height]*q_kji[4] + P_28[x,y,height]*q_kji[5] + P_29[x,y,height]*q_kji[6]))
#
# NameError: name 'x' is not defined

# %%
n2_n1_frac
# Out:
# 0.00010796765578685547

# %%
data.atom_H.populations[1,x,y,height].data/data.atom_H.populations[0,x,y,height].data
# Out:
# 0.0016405674272143569

# %% [markdown]
# ## Calculate ratio for whole column

# %%
height_len = len(data.atmos.height_scale[0,0,:].data)

# %%
q_kij_ar = np.zeros((7, height_len))
q_kji_ar = np.zeros((7, height_len))
n2_n1_frac_height = np.zeros(height_len)

# %%
height_len
# Out:
# 467

# %%
x = 62
y = 63
#Loop over height
for height in range(height_len):
    matrix = np.array([[1, -p_34[x,y,height], -p_35[x,y,height], -p_36[x,y,height], -p_37[x,y,height], -p_38[x,y,height], -p_39[x,y,height]],
                       [-p_43[x,y,height], 1, -p_45[x,y,height], -p_46[x,y,height], -p_47[x,y,height], -p_48[x,y,height], -p_49[x,y,height]],
                       [-p_53[x,y,height], -p_54[x,y,height], 1, -p_56[x,y,height], -p_57[x,y,height], -p_58[x,y,height], -p_59[x,y,height]],
                       [-p_63[x,y,height], -p_64[x,y,height], -p_65[x,y,height], 1, -p_67[x,y,height], -p_68[x,y,height], -p_69[x,y,height]],
                       [-p_73[x,y,height], -p_74[x,y,height], -p_75[x,y,height], -p_76[x,y,height], 1, -p_78[x,y,height], -p_79[x,y,height]],
                       [-p_83[x,y,height], -p_84[x,y,height], -p_85[x,y,height], -p_86[x,y,height], -p_87[x,y,height], 1, -p_89[x,y,height]],
                       [-p_93[x,y,height], -p_94[x,y,height], -p_95[x,y,height], -p_96[x,y,height], -p_97[x,y,height], -p_98[x,y,height], 1]
                      ])
    sol_vector = np.array([p_32[x,y,height], p_42[x,y,height], p_52[x,y,height], p_62[x,y,height], p_72[x,y,height], p_82[x,y,height], p_92[x,y,height]])
    
    q_kij_ar[:,height] = np.linalg.inv(matrix).dot(sol_vector)
    q_kji_ar[:,height] = 1-q_kij_ar[:,height]
    
    n2_n1_frac_height[height] = ((P_12[x,y,height] + P_13[x,y,height]*q_kij_ar[0,height] + P_14[x,y,height]*q_kij_ar[1,height] + P_15[x,y,height]*q_kij_ar[2,height] + P_16[x,y,height]*q_kij_ar[3,height] + P_17[x,y,height]*q_kij_ar[4,height] + P_18[x,y,height]*q_kij_ar[5,height] + P_19[x,y,height]*q_kij_ar[6,height])/
              (P_21[x,y,height] + P_23[x,y,height]*q_kji_ar[0,height] + P_24[x,y,height]*q_kji_ar[1,height] + P_25[x,y,height]*q_kji_ar[2,height] + P_26[x,y,height]*q_kji_ar[3,height] + P_27[x,y,height]*q_kji_ar[4,height] + P_28[x,y,height]*q_kji_ar[5,height] + P_29[x,y,height]*q_kji_ar[6,height]))

# %%
n2_n1_frac_rh = data.atom_H.populations[1,x,y,:].data/data.atom_H.populations[0,x,y,:].data

# %%
plt.plot(data.atmos.height_scale[0,0,:].data, n2_n1_frac_height, label='interlocking')
plt.plot(data.atmos.height_scale[0,0,:].data, n2_n1_frac_rh, label='rh')
plt.yscale('log')

# %%
plt.plot(data.atmos.height_scale[0,0,:].data/1e6, (n2_n1_frac_rh-n2_n1_frac_height)/n2_n1_frac_rh)
#plt.yscale('log')
plt.xlim([0,5])
# Out:
# (0.0, 5.0)

# %%
plt.figure(figsize=[10,6])
plt.plot(data.atmos.height_scale[0,0,:].data, q_kij_ar[0,:], label='q321')
plt.plot(data.atmos.height_scale[0,0,:].data, q_kij_ar[1,:], label='q421')
plt.plot(data.atmos.height_scale[0,0,:].data, q_kij_ar[2,:], label='q521')
plt.plot(data.atmos.height_scale[0,0,:].data, q_kij_ar[3,:], label='q621')
plt.plot(data.atmos.height_scale[0,0,:].data, q_kij_ar[4,:], label='q721')
plt.plot(data.atmos.height_scale[0,0,:].data, q_kij_ar[5,:], label='q821')
plt.plot(data.atmos.height_scale[0,0,:].data, q_kij_ar[6,:], label='q921')
#plt.yscale('log')
plt.legend()
#plt.xlim(0.2e6, 1.5e6)

# %% [markdown]
# ## n_6/n_2

# %%
# Lyman series n=1, rh=0
lyman_start = 0
lyman_end = 6+1
lyman_cont = 0

lyman_rates_line = data.atom_H.Cij_line[lyman_start:lyman_end,...].data + data.atom_H.Rij_line[lyman_start:lyman_end,...].data
lyman_rates_cont = data.atom_H.Cij_continuum[lyman_cont,...].data + data.atom_H.Rij_continuum[lyman_cont,...].data
lyman_rates_out =  np.concatenate((lyman_rates_line, lyman_rates_cont[np.newaxis]))


P_1 = np.sum(lyman_rates_out, axis=0)
p_12 = lyman_rates_out[0,...]/P_1
p_13 = lyman_rates_out[1,...]/P_1
p_14 = lyman_rates_out[2,...]/P_1
p_15 = lyman_rates_out[3,...]/P_1
p_16 = lyman_rates_out[4,...]/P_1
p_17 = lyman_rates_out[5,...]/P_1
p_18 = lyman_rates_out[6,...]/P_1
p_19 = lyman_rates_out[7,...]/P_1

# %%
# Paschen series n=3, rh=2
paschen_start = 13
paschen_end = 17+1
paschen_cont = 2

paschen_rates_line_lyman = data.atom_H.Cji_line[1,...].data + data.atom_H.Rji_line[1,...].data
paschen_rates_line_balmer = data.atom_H.Cji_line[7,...].data + data.atom_H.Rji_line[7,...].data
paschen_rates_line = data.atom_H.Cij_line[paschen_start:paschen_end,...].data + data.atom_H.Rij_line[paschen_start:paschen_end,...].data
paschen_rates_cont = data.atom_H.Cij_continuum[paschen_cont,...].data + data.atom_H.Rij_continuum[paschen_cont,...].data
paschen_rates_out =  np.concatenate((paschen_rates_line_lyman[np.newaxis], paschen_rates_line_balmer[np.newaxis], paschen_rates_line, paschen_rates_cont[np.newaxis]))


P_3 = np.sum(paschen_rates_out, axis=0)
p_31 = paschen_rates_out[0,...]/P_3
p_32 = paschen_rates_out[1,...]/P_3
p_34 = paschen_rates_out[2,...]/P_3
p_35 = paschen_rates_out[3,...]/P_3
p_36 = paschen_rates_out[4,...]/P_3
p_37 = paschen_rates_out[5,...]/P_3
p_38 = paschen_rates_out[6,...]/P_3
p_39 = paschen_rates_out[7,...]/P_3

# %%
# Brackett series n=4, rh=3
brackett_start = 18
brackett_end = 21+1
brackett_cont = 3

brackett_rates_line_lyman = data.atom_H.Cji_line[2,...].data + data.atom_H.Rji_line[2,...].data
brackett_rates_line_balmer = data.atom_H.Cji_line[8,...].data + data.atom_H.Rji_line[8,...].data
brackett_rates_line_paschen = data.atom_H.Cji_line[13,...].data + data.atom_H.Rji_line[13,...].data
brackett_rates_line = data.atom_H.Cij_line[brackett_start:brackett_end,...].data + data.atom_H.Rij_line[brackett_start:brackett_end,...].data
brackett_rates_cont = data.atom_H.Cij_continuum[brackett_cont,...].data + data.atom_H.Rij_continuum[brackett_cont,...].data
brackett_rates_out =  np.concatenate((brackett_rates_line_lyman[np.newaxis], brackett_rates_line_balmer[np.newaxis], brackett_rates_line_paschen[np.newaxis], brackett_rates_line, brackett_rates_cont[np.newaxis]))


P_4 = np.sum(brackett_rates_out, axis=0)
p_41 = brackett_rates_out[0,...]/P_4
p_42 = brackett_rates_out[1,...]/P_4
p_43 = brackett_rates_out[2,...]/P_4
p_45 = brackett_rates_out[3,...]/P_4
p_46 = brackett_rates_out[4,...]/P_4
p_47 = brackett_rates_out[5,...]/P_4
p_48 = brackett_rates_out[6,...]/P_4
p_49 = brackett_rates_out[7,...]/P_4

# %%
# Pfund series n=5, rh=4
pfund_start = 22
pfund_end = 24+1
pfund_cont = 4

pfund_rates_line_lyman = data.atom_H.Cji_line[3,...].data + data.atom_H.Rji_line[3,...].data
pfund_rates_line_balmer = data.atom_H.Cji_line[9,...].data + data.atom_H.Rji_line[9,...].data
pfund_rates_line_paschen = data.atom_H.Cji_line[14,...].data + data.atom_H.Rji_line[14,...].data
pfund_rates_line_brackett = data.atom_H.Cji_line[18,...].data + data.atom_H.Rji_line[18,...].data
pfund_rates_line = data.atom_H.Cij_line[pfund_start:pfund_end,...].data + data.atom_H.Rij_line[pfund_start:pfund_end,...].data
pfund_rates_cont = data.atom_H.Cij_continuum[pfund_cont,...].data + data.atom_H.Rij_continuum[pfund_cont,...].data
pfund_rates_out =  np.concatenate((pfund_rates_line_lyman[np.newaxis], pfund_rates_line_balmer[np.newaxis], pfund_rates_line_paschen[np.newaxis], pfund_rates_line_brackett[np.newaxis], pfund_rates_line, pfund_rates_cont[np.newaxis]))


P_5 = np.sum(pfund_rates_out, axis=0)
p_51 = pfund_rates_out[0,...]/P_5
p_52 = pfund_rates_out[1,...]/P_5
p_53 = pfund_rates_out[2,...]/P_5
p_54 = pfund_rates_out[3,...]/P_5
p_56 = pfund_rates_out[4,...]/P_5
p_57 = pfund_rates_out[5,...]/P_5
p_58 = pfund_rates_out[6,...]/P_5
p_59 = pfund_rates_out[7,...]/P_5

# %%
# Humphreys n=6, rh=5
humphreys_start = 25
humphreys_end = 26+1
humphreys_cont = 5

humphreys_rates_line_lyman = data.atom_H.Cji_line[4,...].data + data.atom_H.Rji_line[4,...].data
humphreys_rates_line_balmer = data.atom_H.Cji_line[10,...].data + data.atom_H.Rji_line[10,...].data
humphreys_rates_line_paschen = data.atom_H.Cji_line[15,...].data + data.atom_H.Rji_line[15,...].data
humphreys_rates_line_brackett = data.atom_H.Cji_line[19,...].data + data.atom_H.Rji_line[19,...].data
humphreys_rates_line_pfund = data.atom_H.Cji_line[22,...].data + data.atom_H.Rji_line[22,...].data
humphreys_rates_line = data.atom_H.Cij_line[humphreys_start:humphreys_end,...].data + data.atom_H.Rij_line[humphreys_start:humphreys_end,...].data
humphreys_rates_cont = data.atom_H.Cij_continuum[humphreys_cont,...].data + data.atom_H.Rij_continuum[humphreys_cont,...].data
humphreys_rates_out =  np.concatenate((humphreys_rates_line_lyman[np.newaxis], humphreys_rates_line_balmer[np.newaxis], humphreys_rates_line_paschen[np.newaxis], humphreys_rates_line_brackett[np.newaxis], humphreys_rates_line_pfund[np.newaxis], humphreys_rates_line, humphreys_rates_cont[np.newaxis]))


P_6 = np.sum(humphreys_rates_out, axis=0)
p_61 = humphreys_rates_out[0,...]/P_6
p_62 = humphreys_rates_out[1,...]/P_6
p_63 = humphreys_rates_out[2,...]/P_6
p_64 = humphreys_rates_out[3,...]/P_6
p_65 = humphreys_rates_out[4,...]/P_6
p_67 = humphreys_rates_out[5,...]/P_6
p_68 = humphreys_rates_out[6,...]/P_6
p_69 = humphreys_rates_out[7,...]/P_6

# %%
# Kriki2 n=8, rh=7
#kriki_start = 27
#kriki_end = 27+1
kriki2_cont = 7

kriki2_rates_line_lyman = data.atom_H.Cji_line[6,...].data + data.atom_H.Rji_line[6,...].data
kriki2_rates_line_balmer = data.atom_H.Cji_line[12,...].data + data.atom_H.Rji_line[12,...].data
kriki2_rates_line_paschen = data.atom_H.Cji_line[17,...].data + data.atom_H.Rji_line[17,...].data
kriki2_rates_line_brackett = data.atom_H.Cji_line[21,...].data + data.atom_H.Rji_line[21,...].data
kriki2_rates_line_pfund = data.atom_H.Cji_line[24,...].data + data.atom_H.Rji_line[24,...].data
kriki2_rates_line_humphreys = data.atom_H.Cji_line[26,...].data + data.atom_H.Rji_line[26,...].data
kriki2_rates_line_kriki = data.atom_H.Cji_line[27,...].data + data.atom_H.Rji_line[27,...].data
#kriki_rates_line = data.atom_H.Cij_line[kriki_start:kriki_end,...].data + data.atom_H.Rij_line[kriki_start:kriki_end,...].data
kriki2_rates_cont = data.atom_H.Cij_continuum[kriki2_cont,...].data + data.atom_H.Rij_continuum[kriki2_cont,...].data
kriki2_rates_out =  np.concatenate((kriki2_rates_line_lyman[np.newaxis], kriki2_rates_line_balmer[np.newaxis], kriki2_rates_line_paschen[np.newaxis], kriki2_rates_line_brackett[np.newaxis], kriki2_rates_line_pfund[np.newaxis], kriki2_rates_line_humphreys[np.newaxis], kriki2_rates_line_kriki[np.newaxis], kriki2_rates_cont[np.newaxis]))


P_8 = np.sum(kriki2_rates_out, axis=0)
p_81 = kriki2_rates_out[0,...]/P_8
p_82 = kriki2_rates_out[1,...]/P_8
p_83 = kriki2_rates_out[2,...]/P_8
p_84 = kriki2_rates_out[3,...]/P_8
p_85 = kriki2_rates_out[4,...]/P_8
p_86 = kriki2_rates_out[5,...]/P_8
p_87 = kriki2_rates_out[6,...]/P_8
p_89 = kriki2_rates_out[7,...]/P_8

# %%
# Continuum n=9, rh=8

rates_cont = data.atom_H.Cji_continuum.data + data.atom_H.Rji_continuum.data

P_9 = np.sum(rates_cont, axis=0)
p_91 = rates_cont[0,...]/P_9
p_92 = rates_cont[1,...]/P_9
p_93 = rates_cont[2,...]/P_9
p_94 = rates_cont[3,...]/P_9
p_95 = rates_cont[4,...]/P_9
p_96 = rates_cont[5,...]/P_9
p_97 = rates_cont[6,...]/P_9
p_98 = rates_cont[7,...]/P_9

# %%
P_21 = data.atom_H.Cji_line[0,...].data + data.atom_H.Rji_line[0,...].data
P_23 = data.atom_H.Cij_line[7,...].data + data.atom_H.Rij_line[7,...].data
P_24 = data.atom_H.Cij_line[8,...].data + data.atom_H.Rij_line[8,...].data
P_25 = data.atom_H.Cij_line[9,...].data + data.atom_H.Rij_line[9,...].data
P_26 = data.atom_H.Cij_line[10,...].data + data.atom_H.Rij_line[10,...].data
P_27 = data.atom_H.Cij_line[11,...].data + data.atom_H.Rij_line[11,...].data
P_28 = data.atom_H.Cij_line[12,...].data + data.atom_H.Rij_line[12,...].data
P_29 = data.atom_H.Cij_continuum[1,...].data + data.atom_H.Rij_continuum[1,...].data

# %%
P_71 = data.atom_H.Cji_line[5,...].data + data.atom_H.Rji_line[5,...].data
P_72 = data.atom_H.Cji_line[11,...].data + data.atom_H.Rji_line[11,...].data
P_73 = data.atom_H.Cji_line[16,...].data + data.atom_H.Rji_line[16,...].data
P_74 = data.atom_H.Cji_line[20,...].data + data.atom_H.Rji_line[20,...].data
P_75 = data.atom_H.Cji_line[23,...].data + data.atom_H.Rji_line[23,...].data
P_76 = data.atom_H.Cji_line[25,...].data + data.atom_H.Rji_line[25,...].data
P_78 = data.atom_H.Cij_line[27,...].data + data.atom_H.Rij_line[27,...].data
P_79 = data.atom_H.Cij_continuum[6,...].data + data.atom_H.Rij_continuum[6,...].data

# %% [markdown]
# ## Calculate ratio for whole column

# %%
height_len = len(data.atmos.height_scale[0,0,:].data)

# %%
q_kij_ar = np.zeros((7, height_len))
q_kji_ar = np.zeros((7, height_len))
n2_n1_frac_height = np.zeros(height_len)

# %%
height_len
# Out:
# 467

# %%
x = 352
y = 271
#Loop over height
for height in range(height_len):
    matrix = np.array([[1, -p_13[x,y,height], -p_14[x,y,height], -p_15[x,y,height], -p_16[x,y,height], -p_18[x,y,height], -p_19[x,y,height]],
                       [-p_31[x,y,height], 1, -p_34[x,y,height], -p_35[x,y,height], -p_36[x,y,height], -p_38[x,y,height], -p_39[x,y,height]],
                       [-p_41[x,y,height], -p_43[x,y,height], 1, -p_45[x,y,height], -p_46[x,y,height], -p_48[x,y,height], -p_49[x,y,height]],
                       [-p_51[x,y,height], -p_53[x,y,height], -p_54[x,y,height], 1, -p_56[x,y,height], -p_58[x,y,height], -p_59[x,y,height]],
                       [-p_61[x,y,height], -p_63[x,y,height], -p_64[x,y,height], -p_65[x,y,height], 1, -p_68[x,y,height], -p_69[x,y,height]],
                       [-p_81[x,y,height], -p_83[x,y,height], -p_84[x,y,height], -p_85[x,y,height], -p_86[x,y,height], 1, -p_89[x,y,height]],
                       [-p_91[x,y,height], -p_93[x,y,height], -p_94[x,y,height], -p_95[x,y,height], -p_96[x,y,height], -p_98[x,y,height], 1]
                      ])
    sol_vector = np.array([p_17[x,y,height], p_37[x,y,height], p_47[x,y,height], p_57[x,y,height], p_67[x,y,height], p_87[x,y,height], p_97[x,y,height]])
    
    q_kij_ar[:,height] = np.linalg.inv(matrix).dot(sol_vector)
    q_kji_ar[:,height] = 1-q_kij_ar[:,height]
    
    n2_n1_frac_height[height] = ((P_21[x,y,height]*q_kij_ar[0,height]  + P_23[x,y,height]*q_kij_ar[1,height] + P_24[x,y,height]*q_kij_ar[2,height] + P_25[x,y,height]*q_kij_ar[3,height] + P_26[x,y,height] + P_27[x,y,height]*q_kij_ar[4,height] + P_28[x,y,height]*q_kij_ar[5,height] + P_29[x,y,height]*q_kij_ar[6,height])/
                                 (P_71[x,y,height]*q_kji_ar[0,height] + P_72[x,y,height] + P_73[x,y,height]*q_kji_ar[1,height] + P_74[x,y,height]*q_kji_ar[2,height] + P_75[x,y,height]*q_kji_ar[3,height] + P_76[x,y,height]*q_kji_ar[4,height] + P_78[x,y,height]*q_kji_ar[5,height] + P_79[x,y,height]*q_kji_ar[6,height]))

# %%
n2_n1_frac_rh = data.atom_H.populations[6,x,y,:].data/data.atom_H.populations[1,x,y,:].data

# %%
plt.plot(data.atmos.height_scale[0,0,:].data/1e6, n2_n1_frac_height, label='interlocking')
plt.plot(data.atmos.height_scale[0,0,:].data/1e6, n2_n1_frac_rh, label='rh')
plt.legend()
plt.yscale('log')
plt.xlim([0,2])
# Out:
# (0.0, 2.0)

# %%
plt.plot(data.atmos.height_scale[0,0,:].data, (n2_n1_frac_rh-n2_n1_frac_height)/n2_n1_frac_rh)
#plt.yscale('log')

# %%
plt.figure(figsize=[10,6])
plt.plot(data.atmos.height_scale[0,0,:].data, q_kij_ar[0,:], label='q321')
plt.plot(data.atmos.height_scale[0,0,:].data, q_kij_ar[1,:], label='q421')
plt.plot(data.atmos.height_scale[0,0,:].data, q_kij_ar[2,:], label='q521')
plt.plot(data.atmos.height_scale[0,0,:].data, q_kij_ar[3,:], label='q621')
plt.plot(data.atmos.height_scale[0,0,:].data, q_kij_ar[4,:], label='q721')
plt.plot(data.atmos.height_scale[0,0,:].data, q_kij_ar[5,:], label='q821')
plt.plot(data.atmos.height_scale[0,0,:].data, q_kij_ar[6,:], label='q921')
plt.yscale('log')
plt.legend()
#plt.xlim(0.0, 1.5e6)
